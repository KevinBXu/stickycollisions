# %%
import pickle
import cupy as np 

with open('consistency.pkl', 'rb') as f:
    mean_spacing_dict = pickle.load(f)
print(mean_spacing_dict)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       2 import cupy as np
#       4 with open('consistency.pkl', 'rb') as f:
# ----> 5     mean_spacing_dict = pickle.load(f)
#       6 print(mean_spacing_dict)
#
# EOFError: Ran out of input
