# %%
import numpy as np

# %%
angles = np.array([20, 23, 26, 30, 34, 40, 44, 48]) * np.pi / 180
velocities = np.array([180, 160, 150, 140, 130, 120, 110, 100])

# %%
times = velocities * np.sin(angles) / 32
max_height = -16 * times ** 2 + velocities * np.sin(angles) * times 
x = velocities * times * np.cos(angles)

# %%
for i in range(len(times)):
    print(times[i], max_height[i], x[i])
# Out:
# 1.9238633062068866 59.220000335508686 325.4112274038105
# 1.9536556424463685 61.06832590820052 287.7359201354604
# 2.0548647505738002 67.55950629041162 277.0350305648632
# 2.1874999999999996 76.56249999999997 265.2202799089843
# 2.271721170349909 82.57147321305537 244.83448659654232
# 2.410453536324522 92.96458001247031 221.58174442774674
# 2.387888148452803 91.23215695234171 188.94732823329778
# 2.3223275796168568 86.2912861927854 155.3940461512927

# %%
nearest_neighbor = np.sqrt(-4 / np.pi * np.log(1 - uniform_dist))
