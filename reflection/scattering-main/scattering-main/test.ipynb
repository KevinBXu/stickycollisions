# %%
import numpy as np

S = np.array([[0.5+0.49j, -0.5+0.51j], [-0.5+0.51j,  0.5+0.49j]])

# %%
np.linalg.eig(S)
# Out:
# (array([1.0000000e+00-0.02j, 6.9388939e-17+1.j  ]),
#  array([[ 0.70710678+0.00000000e+00j,  0.70710678-4.81620970e-18j],
#         [-0.70710678-2.59446115e-17j,  0.70710678+0.00000000e+00j]]))
