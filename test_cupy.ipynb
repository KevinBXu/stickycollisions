# %%
import numpy as np
import cupy as cp

# %%
x = np.random.rand(10000, 10000)
y = np.random.rand(10000, 10000)

# %%
z = x @ y

# %%
a = cp.asarray(x)
b = cp.asarray(y)

# %%
c = a @ b

# %%
print(c.device)
# Out:
# <CUDA Device 0>

# %%
cp.cuda.is_available()
# Out:
# True
